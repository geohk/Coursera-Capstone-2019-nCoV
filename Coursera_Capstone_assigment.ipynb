# %% [markdown]
# In this assignment, you will be required to explore, segment, and cluster the neighborhoods in the city of Toronto. However, unlike New York, the neighborhood data is not readily available on the internet. What is interesting about the field of data science is that each project can be challenging in its unique way, so you need to learn to be agile and refine the skill to learn new libraries and tools quickly depending on the project.
#
# For the Toronto neighborhood data, a Wikipedia page exists that has all the information we need to explore and cluster the neighborhoods in Toronto. You will be required to scrape the Wikipedia page and wrangle the data, clean it, and then read it into a pandas dataframe so that it is in a structured format like the New York dataset.
#
# Once the data is in a structured format, you can replicate the analysis that we did to the New York City dataset to explore and cluster the neighborhoods in the city of Toronto.
#
# Your submission will be a link to your Jupyter Notebook on your Github repository.

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import json # library to handle JSON files
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
from bs4 import BeautifulSoup
import lxml
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.3.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# # Question 1
# Use the BeautifulSoup package or any other way you are comfortable with to transform the data in the table on the Wikipedia page into the above pandas dataframe
# Importing lib to get data in required format

# %%
# download data and parse it:
r = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
soup = BeautifulSoup(r.text, 'html.parser')
table=soup.find('table', attrs={'class':'wikitable sortable'})

table1=""
for tr in table.find_all('tr'):
    row1=""
    for tds in tr.find_all('td'):
        row1=row1+","+tds.text
    table1=table1+row1[1:]
print(table1)
# Out:
# M1A,Not assigned,Not assigned
# M2A,Not assigned,Not assigned
# M3A,North York,Parkwoods
# M4A,North York,Victoria Village
# M5A,Downtown Toronto,Harbourfront
# M6A,North York,Lawrence Heights
# M6A,North York,Lawrence Manor
# M7A,Downtown Toronto,Queen's Park
# M8A,Not assigned,Not assigned
# M9A,Queen's Park,Not assigned
# M1B,Scarborough,Rouge
# M1B,Scarborough,Malvern
# M2B,Not assigned,Not assigned
# M3B,North York,Don Mills North
# M4B,East York,Woodbine Gardens
# M4B,East York,Parkview Hill
# M5B,Downtown Toronto,Ryerson
# M5B,Downtown Toronto,Garden District
# M6B,North York,Glencairn
# M7B,Not assigned,Not assigned
# M8B,Not assigned,Not assigned
# M9B,Etobicoke,Cloverdale
# M9B,Etobicoke,Islington
# M9B,Etobicoke,Martin Grove
# M9B,Etobicoke,Princess Gardens
# M9B,Etobicoke,West Deane Park
# M1C,Scarborough,Highland Creek
# M1C,Scarborough,Rouge Hill
# M1C,Scarborough,Port Union
# M2C,Not assigned,Not assigned
# M3C,North York,Flemingdon Park
# M3C,North York,Don Mills South
# M4C,East York,Woodbine Heights
# M5C,Downtown Toronto,St. James Town
# M6C,York,Humewood-Cedarvale
# M7C,Not assigned,Not assigned
# M8C,Not assigned,Not assigned
# M9C,Etobicoke,Bloordale Gardens
# M9C,Etobicoke,Eringate
# M9C,Etobicoke,Markland Wood
# M9C,Etobicoke,Old Burnhamthorpe
# M1E,Scarborough,Guildwood
# M1E,Scarborough,Morningside
# M1E,Scarborough,West Hill
# M2E,Not assigned,Not assigned
# M3E,Not assigned,Not assigned
# M4E,East Toronto,The Beaches
# M5E,Downtown Toronto,Berczy Park
# M6E,York,Caledonia-Fairbanks
# M7E,Not assigned,Not assigned
# M8E,Not assigned,Not assigned
# M9E,Not assigned,Not assigned
# M1G,Scarborough,Woburn
# M2G,Not assigned,Not assigned
# M3G,Not assigned,Not assigned
# M4G,East York,Leaside
# M5G,Downtown Toronto,Central Bay Street
# M6G,Downtown Toronto,Christie
# M7G,Not assigned,Not assigned
# M8G,Not assigned,Not assigned
# M9G,Not assigned,Not assigned
# M1H,Scarborough,Cedarbrae
# M2H,North York,Hillcrest Village
# M3H,North York,Bathurst Manor
# M3H,North York,Downsview North
# M3H,North York,Wilson Heights
# M4H,East York,Thorncliffe Park
# M5H,Downtown Toronto,Adelaide
# M5H,Downtown Toronto,King
# M5H,Downtown Toronto,Richmond
# M6H,West Toronto,Dovercourt Village
# M6H,West Toronto,Dufferin
# M7H,Not assigned,Not assigned
# M8H,Not assigned,Not assigned
# M9H,Not assigned,Not assigned
# M1J,Scarborough,Scarborough Village
# M2J,North York,Fairview
# M2J,North York,Henry Farm
# M2J,North York,Oriole
# M3J,North York,Northwood Park
# M3J,North York,York University
# M4J,East York,East Toronto
# M5J,Downtown Toronto,Harbourfront East
# M5J,Downtown Toronto,Toronto Islands
# M5J,Downtown Toronto,Union Station
# M6J,West Toronto,Little Portugal
# M6J,West Toronto,Trinity
# M7J,Not assigned,Not assigned
# M8J,Not assigned,Not assigned
# M9J,Not assigned,Not assigned
# M1K,Scarborough,East Birchmount Park
# M1K,Scarborough,Ionview
# M1K,Scarborough,Kennedy Park
# M2K,North York,Bayview Village
# M3K,North York,CFB Toronto
# M3K,North York,Downsview East
# M4K,East Toronto,The Danforth West
# M4K,East Toronto,Riverdale
# M5K,Downtown Toronto,Design Exchange
# M5K,Downtown Toronto,Toronto Dominion Centre
# M6K,West Toronto,Brockton
# M6K,West Toronto,Exhibition Place
# M6K,West Toronto,Parkdale Village
# M7K,Not assigned,Not assigned
# M8K,Not assigned,Not assigned
# M9K,Not assigned,Not assigned
# M1L,Scarborough,Clairlea
# M1L,Scarborough,Golden Mile
# M1L,Scarborough,Oakridge
# M2L,North York,Silver Hills
# M2L,North York,York Mills
# M3L,North York,Downsview West
# M4L,East Toronto,The Beaches West
# M4L,East Toronto,India Bazaar
# M5L,Downtown Toronto,Commerce Court
# M5L,Downtown Toronto,Victoria Hotel
# M6L,North York,Downsview
# M6L,North York,North Park
# M6L,North York,Upwood Park
# M7L,Not assigned,Not assigned
# M8L,Not assigned,Not assigned
# M9L,North York,Humber Summit
# M1M,Scarborough,Cliffcrest
# M1M,Scarborough,Cliffside
# M1M,Scarborough,Scarborough Village West
# M2M,North York,Newtonbrook
# M2M,North York,Willowdale
# M3M,North York,Downsview Central
# M4M,East Toronto,Studio District
# M5M,North York,Bedford Park
# M5M,North York,Lawrence Manor East
# M6M,York,Del Ray
# M6M,York,Keelesdale
# M6M,York,Mount Dennis
# M6M,York,Silverthorn
# M7M,Not assigned,Not assigned
# M8M,Not assigned,Not assigned
# M9M,North York,Emery
# M9M,North York,Humberlea
# M1N,Scarborough,Birch Cliff
# M1N,Scarborough,Cliffside West
# M2N,North York,Willowdale South
# M3N,North York,Downsview Northwest
# M4N,Central Toronto,Lawrence Park
# M5N,Central Toronto,Roselawn
# M6N,York,The Junction North
# M6N,York,Runnymede
# M7N,Not assigned,Not assigned
# M8N,Not assigned,Not assigned
# M9N,York,Weston
# M1P,Scarborough,Dorset Park
# M1P,Scarborough,Scarborough Town Centre
# M1P,Scarborough,Wexford Heights
# M2P,North York,York Mills West
# M3P,Not assigned,Not assigned
# M4P,Central Toronto,Davisville North
# M5P,Central Toronto,Forest Hill North
# M5P,Central Toronto,Forest Hill West
# M6P,West Toronto,High Park
# M6P,West Toronto,The Junction South
# M7P,Not assigned,Not assigned
# M8P,Not assigned,Not assigned
# M9P,Etobicoke,Westmount
# M1R,Scarborough,Maryvale
# M1R,Scarborough,Wexford
# M2R,North York,Willowdale West
# M3R,Not assigned,Not assigned
# M4R,Central Toronto,North Toronto West
# M5R,Central Toronto,The Annex
# M5R,Central Toronto,North Midtown
# M5R,Central Toronto,Yorkville
# M6R,West Toronto,Parkdale
# M6R,West Toronto,Roncesvalles
# M7R,Mississauga,Canada Post Gateway Processing Centre
# M8R,Not assigned,Not assigned
# M9R,Etobicoke,Kingsview Village
# M9R,Etobicoke,Martin Grove Gardens
# M9R,Etobicoke,Richview Gardens
# M9R,Etobicoke,St. Phillips
# M1S,Scarborough,Agincourt
# M2S,Not assigned,Not assigned
# M3S,Not assigned,Not assigned
# M4S,Central Toronto,Davisville
# M5S,Downtown Toronto,Harbord
# M5S,Downtown Toronto,University of Toronto
# M6S,West Toronto,Runnymede
# M6S,West Toronto,Swansea
# M7S,Not assigned,Not assigned
# M8S,Not assigned,Not assigned
# M9S,Not assigned,Not assigned
# M1T,Scarborough,Clarks Corners
# M1T,Scarborough,Sullivan
# M1T,Scarborough,Tam O'Shanter
# M2T,Not assigned,Not assigned
# M3T,Not assigned,Not assigned
# M4T,Central Toronto,Moore Park
# M4T,Central Toronto,Summerhill East
# M5T,Downtown Toronto,Chinatown
# M5T,Downtown Toronto,Grange Park
# M5T,Downtown Toronto,Kensington Market
# M6T,Not assigned,Not assigned
# M7T,Not assigned,Not assigned
# M8T,Not assigned,Not assigned
# M9T,Not assigned,Not assigned
# M1V,Scarborough,Agincourt North
# M1V,Scarborough,L'Amoreaux East
# M1V,Scarborough,Milliken
# M1V,Scarborough,Steeles East
# M2V,Not assigned,Not assigned
# M3V,Not assigned,Not assigned
# M4V,Central Toronto,Deer Park
# M4V,Central Toronto,Forest Hill SE
# M4V,Central Toronto,Rathnelly
# M4V,Central Toronto,South Hill
# M4V,Central Toronto,Summerhill West
# M5V,Downtown Toronto,CN Tower
# M5V,Downtown Toronto,Bathurst Quay
# M5V,Downtown Toronto,Island airport
# M5V,Downtown Toronto,Harbourfront West
# M5V,Downtown Toronto,King and Spadina
# M5V,Downtown Toronto,Railway Lands
# M5V,Downtown Toronto,South Niagara
# M6V,Not assigned,Not assigned
# M7V,Not assigned,Not assigned
# M8V,Etobicoke,Humber Bay Shores
# M8V,Etobicoke,Mimico South
# M8V,Etobicoke,New Toronto
# M9V,Etobicoke,Albion Gardens
# M9V,Etobicoke,Beaumond Heights
# M9V,Etobicoke,Humbergate
# M9V,Etobicoke,Jamestown
# M9V,Etobicoke,Mount Olive
# M9V,Etobicoke,Silverstone
# M9V,Etobicoke,South Steeles
# M9V,Etobicoke,Thistletown
# M1W,Scarborough,L'Amoreaux West
# M2W,Not assigned,Not assigned
# M3W,Not assigned,Not assigned
# M4W,Downtown Toronto,Rosedale
# M5W,Downtown Toronto,Stn A PO Boxes 25 The Esplanade
# M6W,Not assigned,Not assigned
# M7W,Not assigned,Not assigned
# M8W,Etobicoke,Alderwood
# M8W,Etobicoke,Long Branch
# M9W,Etobicoke,Northwest
# M1X,Scarborough,Upper Rouge
# M2X,Not assigned,Not assigned
# M3X,Not assigned,Not assigned
# M4X,Downtown Toronto,Cabbagetown
# M4X,Downtown Toronto,St. James Town
# M5X,Downtown Toronto,First Canadian Place
# M5X,Downtown Toronto,Underground city
# M6X,Not assigned,Not assigned
# M7X,Not assigned,Not assigned
# M8X,Etobicoke,The Kingsway
# M8X,Etobicoke,Montgomery Road
# M8X,Etobicoke,Old Mill North
# M9X,Not assigned,Not assigned
# M1Y,Not assigned,Not assigned
# M2Y,Not assigned,Not assigned
# M3Y,Not assigned,Not assigned
# M4Y,Downtown Toronto,Church and Wellesley
# M5Y,Not assigned,Not assigned
# M6Y,Not assigned,Not assigned
# M7Y,East Toronto,Business Reply Mail Processing Centre 969 Eastern
# M8Y,Etobicoke,Humber Bay
# M8Y,Etobicoke,King's Mill Park
# M8Y,Etobicoke,Kingsway Park South East
# M8Y,Etobicoke,Mimico NE
# M8Y,Etobicoke,Old Mill South
# M8Y,Etobicoke,The Queensway East
# M8Y,Etobicoke,Royal York South East
# M8Y,Etobicoke,Sunnylea
# M9Y,Not assigned,Not assigned
# M1Z,Not assigned,Not assigned
# M2Z,Not assigned,Not assigned
# M3Z,Not assigned,Not assigned
# M4Z,Not assigned,Not assigned
# M5Z,Not assigned,Not assigned
# M6Z,Not assigned,Not assigned
# M7Z,Not assigned,Not assigned
# M8Z,Etobicoke,Kingsway Park South West
# M8Z,Etobicoke,Mimico NW
# M8Z,Etobicoke,The Queensway West
# M8Z,Etobicoke,Royal York South West
# M8Z,Etobicoke,South of Bloor
# M9Z,Not assigned,Not assigned

# %%
#write to csv to furhter process

file=open("toronto.csv","wb")
file.write(bytes(table1,encoding="ascii",errors="ignore"))
# Out:
# 8708

# %%
import pandas as pd
df = pd.read_csv('toronto.csv',header=None)
df.columns=["Postalcode","Borough","Neighbourhood"]
df=df.drop_duplicates()
# skip not assigned boroughs:
df = df.drop(df[(df.Borough == "Not assigned")].index)
df.Neighbourhood.replace("Not assigned", df.Borough, inplace=True)
# Out:
#    Postalcode           Borough  \
# 0         M3A        North York
# 1         M4A        North York
# 2         M5A  Downtown Toronto
# 3         M6A        North York
# 4         M7A  Downtown Toronto
# 5         M9A      Queen's Park
# 6         M1B       Scarborough
# 7         M3B        North York
# 8         M4B         East York
# 9         M5B  Downtown Toronto
# 10        M6B        North York
# 11        M9B         Etobicoke
# 12        M1C       Scarborough
# 13        M3C        North York
# 14        M4C         East York
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                                        Harbourfront
# 3                    Lawrence Heights, Lawrence Manor
# 4                                        Queen's Park
# 5                                        Queen's Park
# 6                                      Rouge, Malvern
# 7                                     Don Mills North
# 8                     Woodbine Gardens, Parkview Hill
# 9                            Ryerson, Garden District
# 10                                          Glencairn
# 11  Cloverdale, Islington, Martin Grove, Princess ...
# 12             Highland Creek, Rouge Hill, Port Union
# 13                   Flemingdon Park, Don Mills South
# 14                                   Woodbine Heights

# %%
# group same postal and borough to single record
result = df.groupby(['Postalcode','Borough'], sort=False).agg( ', '.join)
result
df_new=result.reset_index()
df_new.head(15)
# Out:
#    Postalcode           Borough  \
# 0         M3A        North York
# 1         M4A        North York
# 2         M5A  Downtown Toronto
# 3         M6A        North York
# 4         M7A  Downtown Toronto
# 5         M9A      Queen's Park
# 6         M1B       Scarborough
# 7         M3B        North York
# 8         M4B         East York
# 9         M5B  Downtown Toronto
# 10        M6B        North York
# 11        M9B         Etobicoke
# 12        M1C       Scarborough
# 13        M3C        North York
# 14        M4C         East York
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                                        Harbourfront
# 3                    Lawrence Heights, Lawrence Manor
# 4                                        Queen's Park
# 5                                        Queen's Park
# 6                                      Rouge, Malvern
# 7                                     Don Mills North
# 8                     Woodbine Gardens, Parkview Hill
# 9                            Ryerson, Garden District
# 10                                          Glencairn
# 11  Cloverdale, Islington, Martin Grove, Princess ...
# 12             Highland Creek, Rouge Hill, Port Union
# 13                   Flemingdon Park, Don Mills South
# 14                                   Woodbine Heights

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 3 columns):
# Postalcode       103 non-null object
# Borough          103 non-null object
# Neighbourhood    103 non-null object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# # Question 2
# Use the Geocoder package or the csv file to create dataframe with longitude and latitude values
# We will be using a csv file that has the geographical coordinates of each postal code: http://cocl.us/Geospatial_data

# %%
#add geo location

# %%
address = 'Toronto, ON, Canada'

geolocator = Nominatim(user_agent="Geo exporoer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto, ON, Canada are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto, ON, Canada are 43.653963, -79.387207.

# %%
#add Geo-spatial data
dfll= pd.read_csv("http://cocl.us/Geospatial_data")
dfll.columns=['Postalcode','Latitude','Longitude']
dfll.head()
Toronto_df = pd.merge(df_new,dfll)
Toronto_df
# Out:
#     Postalcode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A      Queen's Park
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# ..         ...               ...
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                                         Harbourfront  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                         Queen's Park  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# # Question 3
# Explore and cluster the neighborhoods in Toronto
# Use geopy library to get the latitude and longitude values of New York City

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude_toronto = location.latitude
longitude_toronto = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude_toronto, longitude_toronto))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
map_toronto = folium.Map(location=[latitude_toronto, longitude_toronto], zoom_start=14)

# add markers to map
for lat, lng, borough, Neighbourhood in zip(Toronto_df['Latitude'], Toronto_df['Longitude'], Toronto_df['Borough'], Toronto_df['Neighbourhood']):
    label = '{}, & {}'.format(Neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'JBREGZ4UNA53HX43WMAD4TQ2X2XJWMX5DPHEZEIZHQA0ACNP' # your Foursquare ID
CLIENT_SECRET = 'VNS40KF3V4MGSWWAV0IGQINZIGIT1EQKNCWBFPOS3QF1JMOJ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JBREGZ4UNA53HX43WMAD4TQ2X2XJWMX5DPHEZEIZHQA0ACNP
# CLIENT_SECRET:VNS40KF3V4MGSWWAV0IGQINZIGIT1EQKNCWBFPOS3QF1JMOJ

# %%
neighborhood_latitude = toronto_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = toronto_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = toronto_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Parkwoods are 43.7532586, -79.3296565.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=JBREGZ4UNA53HX43WMAD4TQ2X2XJWMX5DPHEZEIZHQA0ACNP&client_secret=VNS40KF3V4MGSWWAV0IGQINZIGIT1EQKNCWBFPOS3QF1JMOJ&v=20180605&ll=43.7532586,-79.3296565&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e44039e29ce6a001c673ec9'},
#  'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."},
#   'headerLocation': 'Parkwoods - Donalda',
#   'headerFullLocation': 'Parkwoods - Donalda, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 2,
#   'suggestedBounds': {'ne': {'lat': 43.757758604500005,
#     'lng': -79.32343823984928},
#    'sw': {'lat': 43.7487585955, 'lng': -79.33587476015072}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8d9dcdd5fbbbb6b3003c7b',
#        'name': 'Brookbanks Park',
#        'location': {'address': 'Toronto',
#         'lat': 43.751976046055574,
#         'lng': -79.33214044722958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.751976046055574,
#           'lng': -79.33214044722958}],
#         'distance': 245,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8d9dcdd5fbbbb6b3003c7b-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb11e2075ebb60cd1c4caad',
#        'name': 'Variety Store',
#        'location': {'address': '29 Valley Woods Road',
#         'lat': 43.75197441585782,
#         'lng': -79.33311418516017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75197441585782,
#           'lng': -79.33311418516017}],
#         'distance': 312,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['29 Valley Woods Road', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f9941735',
#          'name': 'Food & Drink Shop',
#          'pluralName': 'Food & Drink Shops',
#          'shortName': 'Food & Drink',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb11e2075ebb60cd1c4caad-1'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#               name         categories        lat        lng
# 0  Brookbanks Park               Park  43.751976 -79.332140
# 1    Variety Store  Food & Drink Shop  43.751974 -79.333114

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# Parkwoods
# Victoria Village
# Regent Park
# Lawrence Heights, Lawrence Manor
# Queen's Park
# Queen's Park
# Malvern, Rouge
# Don Mills North
# Woodbine Gardens, Parkview Hill
# Garden District, Ryerson
# Glencairn
# Princess Gardens, Cloverdale, West Deane Park, Martin Grove, Islington
# Highland Creek , Rouge Hill, Port Union
# Don Mills South, Flemingdon Park
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Old Burnhamthorpe, Markland Wood, Bloordale Gardens, Eringate
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Downsview North, Bathurst Manor, Wilson Heights
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
#
# The Beaches                                                             4
# The Beaches West, India Bazaar                                         18
# The Danforth West, Riverdale                                           42
# The Junction North, Runnymede                                           4
# The Junction South, High Park                                          25
# Thorncliffe Park                                                       19
# Toronto Dominion Centre, Design Exchange                              100
# Toronto Islands, Harbourfront East, Union Station                     100
# University of Toronto, Harbord                                         36
# Victoria Hotel, Commerce Court                                        100
# Victoria Village                                                        5
# Westmount                                                               6
# Weston                                                                  2
# Wexford, Maryvale                                                       4
# Willowdale South                                                       35
# Willowdale West                                                         6
# Willowdale, Newtonbrook                                                 1
# Woburn                                                                  3
# Woodbine Gardens, Parkview Hill                                        13
# Woodbine Heights                                                        9
# York Mills West                                                         4
# York University, Northwood Park                                         4
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Agincourt                                                                5
# Bathurst Quay, Harbourfront West, CN Tower, Sou...                      16
# Bayview Village                                                          4
# Berczy Park                                                             55
# Business Reply Mail Processing Centre 969 Eastern                       17
# CFB Toronto, Downsview East                                              4
# Cabbagetown, St. James Town                                             42
# Caledonia-Fairbanks                                                      4
# Canada Post Gateway Processing Centre                                   12
# Cedarbrae                                                                8
# Central Bay Street                                                      84
# Chinatown, Kensington Market, Grange Park                               80
# Christie                                                                18
# Church and Wellesley                                                    81
# Cliffside West, Birch Cliff                                              4
# Cliffside, Scarborough Village West, Cliffcrest                          2
# Davisville                                                              35
# Davisville North                                                         7
# Don Mills North                                                          5
# Don Mills South, Flemingdon Park                                        21
# Dorset Park, Scarborough Town Centre, Wexford H...                       5
# Downsview                                                                4
# Downsview Central                                                        3
# Downsview North, Bathurst Manor, Wilson Heights                         21
# Downsview Northwest                                                      4
# Dufferin, Dovercourt Village                                            19
# East Birchmount Park, Kennedy Park, Ionview                              4
# East Toronto                                                             3
# Emery, Humberlea                                                         2
# First Canadian Place, Underground city                                 100
# ...                                                                    ...
# South Hill, Forest Hill SE, Rathnelly, Deer Par...                      14
# St. James Town                                                         100
# St. Phillips, Martin Grove Gardens, Kingsview V...                       4
# Stn A PO Boxes 25 The Esplanade                                         94
# Studio District                                                         41
# Sullivan, Clarks Corners, Tam O'Shanter – Sullivan                      13
# Summerhill East, Moore Park                                              4
# Swansea, Runnymede                                                      40
# The Beaches                                                              4
# The Beaches West, India Bazaar                                          18
# The Danforth West, Riverdale                                            42
# The Junction North, Runnymede                                            4
# The Junction South, High Park                                           25
# Thorncliffe Park                                                        19
# Toronto Dominion Centre, Design Exchange                               100
# Toronto Islands, Harbourfront East, Union Station                      100
# University of Toronto, Harbord                                          36
# Victoria Hotel, Commerce Court                                         100
# Victoria Village                                                         5
# Westmount                                                                6
# Weston                                                                   2
# Wexford, Maryvale                                                        4
# Willowdale South                                                        35
# Willowdale West                                                          6
# Willowdale, Newtonbrook                                                  1
# Woburn                                                                   3
# Woodbine Gardens, Parkview Hill                                         13
# Woodbine Heights                                                         9
# York Mills West                                                          4
# York University, Northwood Park                                          4
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Agincourt                                               5               5
# Bathurst Quay, Harbourfront West, CN Tower, Sou...     16              16
# Bayview Village                                         4               4
# Berczy Park                                            55              55
# Business Reply Mail Processing Centre 969 Eastern      17              17
# CFB Toronto, Downsview East                             4               4
# Cabbagetown, St. James Town                            42              42
# Caledonia-Fairbanks                                     4               4
# Canada Post Gateway Processing Centre                  12              12
# Cedarbrae                                               8               8
# Central Bay Street                                     84              84
# Chinatown, Kensington Market, Grange Park              80              80
# Christie                                               18              18
# Church and Wellesley                                   81              81
# Cliffside West, Birch Cliff                             4               4
# Cliffside, Scarborough Village West, Cliffcrest         2               2
# Davisville                                             35              35
# Davisville North                                        7               7
# Don Mills North                                         5               5
# Don Mills South, Flemingdon Park                       21              21
# Dorset Park, Scarborough Town Centre, Wexford H...      5               5
# Downsview                                               4               4
# Downsview Central                                       3               3
# Downsview North, Bathurst Manor, Wilson Heights        21              21
# Downsview Northwest                                     4               4
# Dufferin, Dovercourt Village                           19              19
# East Birchmount Park, Kennedy Park, Ionview             4               4
# East Toronto                                            3               3
# Emery, Humberlea                                        2               2
# First Canadian Place, Underground city                100             100
# ...                                                   ...             ...
# South Hill, Forest Hill SE, Rathnelly, Deer Par...     14              14
# St. James Town                                        100             100
# St. Phillips, Martin Grove Gardens, Kingsview V...      4               4
# Stn A PO Boxes 25 The Esplanade                        94              94
# Studio District                                        41              41
# Sullivan, Clarks Corners, Tam O'Shanter – Sullivan     13              13
# Summerhill East, Moore Park                             4               4
# Swansea, Runnymede                                     40              40
# The Beaches                                             4               4
# The Beaches West, India Bazaar                         18              18
# The Danforth West, Riverdale                           42              42
# The Junction North, Runnymede                           4               4
# The Junction South, High Park                          25              25
# Thorncliffe Park                                       19              19
# Toronto Dominion Centre, Design Exchange              100             100
# Toronto Islands, Harbourfront East, Union Station     100             100
# University of Toronto, Harbord                         36              36
# Victoria Hotel, Commerce Court                        100             100
# Victoria Village                                        5               5
# Westmount                                               6               6
# Weston                                                  2               2
# Wexford, Maryvale                                       4               4
# Willowdale South                                       35              35
# Willowdale West                                         6               6
# Willowdale, Newtonbrook                                 1               1
# Woburn                                                  3               3
# Woodbine Gardens, Parkview Hill                        13              13
# Woodbine Heights                                        9               9
# York Mills West                                         4               4
# York University, Northwood Park                         4               4
#
#                                                     Venue Longitude  \
# Neighborhood
# Agincourt                                                         5
# Bathurst Quay, Harbourfront West, CN Tower, Sou...               16
# Bayview Village                                                   4
# Berczy Park                                                      55
# Business Reply Mail Processing Centre 969 Eastern                17
# CFB Toronto, Downsview East                                       4
# Cabbagetown, St. James Town                                      42
# Caledonia-Fairbanks                                               4
# Canada Post Gateway Processing Centre                            12
# Cedarbrae                                                         8
# Central Bay Street                                               84
# Chinatown, Kensington Market, Grange Park                        80
# Christie                                                         18
# Church and Wellesley                                             81
# Cliffside West, Birch Cliff                                       4
# Cliffside, Scarborough Village West, Cliffcrest                   2
# Davisville                                                       35
# Davisville North                                                  7
# Don Mills North                                                   5
# Don Mills South, Flemingdon Park                                 21
# Dorset Park, Scarborough Town Centre, Wexford H...                5
# Downsview                                                         4
# Downsview Central                                                 3
# Downsview North, Bathurst Manor, Wilson Heights                  21
# Downsview Northwest                                               4
# Dufferin, Dovercourt Village                                     19
# East Birchmount Park, Kennedy Park, Ionview                       4
# East Toronto                                                      3
# Emery, Humberlea                                                  2
# First Canadian Place, Underground city                          100
# ...                                                             ...
# South Hill, Forest Hill SE, Rathnelly, Deer Par...               14
# St. James Town                                                  100
# St. Phillips, Martin Grove Gardens, Kingsview V...                4
# Stn A PO Boxes 25 The Esplanade                                  94
# Studio District                                                  41
# Sullivan, Clarks Corners, Tam O'Shanter – Sullivan               13
# Summerhill East, Moore Park                                       4
# Swansea, Runnymede                                               40
# The Beaches                                                       4
# The Beaches West, India Bazaar                                   18
# The Danforth West, Riverdale                                     42
# The Junction North, Runnymede                                     4
# The Junction South, High Park                                    25
# Thorncliffe Park                                                 19
# Toronto Dominion Centre, Design Exchange                        100
# Toronto Islands, Harbourfront East, Union Station               100
# University of Toronto, Harbord                                   36
# Victoria Hotel, Commerce Court                                  100
# Victoria Village                                                  5
# Westmount                                                         6
# Weston                                                            2
# Wexford, Maryvale                                                 4
# Willowdale South                                                 35
# Willowdale West                                                   6
# Willowdale, Newtonbrook                                           1
# Woburn                                                            3
# Woodbine Gardens, Parkview Hill                                  13
# Woodbine Heights                                                  9
# York Mills West                                                   4
# York University, Northwood Park                                   4
#
#                                                     Venue Category
# Neighborhood
# Agincourt                                                        5
# Bathurst Quay, Harbourfront West, CN Tower, Sou...              16
# Bayview Village                                                  4
# Berczy Park                                                     55
# Business Reply Mail Processing Centre 969 Eastern               17
# CFB Toronto, Downsview East                                      4
# Cabbagetown, St. James Town                                     42
# Caledonia-Fairbanks                                              4
# Canada Post Gateway Processing Centre                           12
# Cedarbrae                                                        8
# Central Bay Street                                              84
# Chinatown, Kensington Market, Grange Park                       80
# Christie                                                        18
# Church and Wellesley                                            81
# Cliffside West, Birch Cliff                                      4
# Cliffside, Scarborough Village West, Cliffcrest                  2
# Davisville                                                      35
# Davisville North                                                 7
# Don Mills North                                                  5
# Don Mills South, Flemingdon Park                                21
# Dorset Park, Scarborough Town Centre, Wexford H...               5
# Downsview                                                        4
# Downsview Central                                                3
# Downsview North, Bathurst Manor, Wilson Heights                 21
# Downsview Northwest                                              4
# Dufferin, Dovercourt Village                                    19
# East Birchmount Park, Kennedy Park, Ionview                      4
# East Toronto                                                     3
# Emery, Humberlea                                                 2
# First Canadian Place, Underground city                         100
# ...                                                            ...
# South Hill, Forest Hill SE, Rathnelly, Deer Par...              14
# St. James Town                                                 100
# St. Phillips, Martin Grove Gardens, Kingsview V...               4
# Stn A PO Boxes 25 The Esplanade                                 94
# Studio District                                                 41
# Sullivan, Clarks Corners, Tam O'Shanter – Sullivan              13
# Summerhill East, Moore Park                                      4
# Swansea, Runnymede                                              40
# The Beaches                                                      4
# The Beaches West, India Bazaar                                  18
# The Danforth West, Riverdale                                    42
# The Junction North, Runnymede                                    4
# The Junction South, High Park                                   25
# Thorncliffe Park                                                19
# Toronto Dominion Centre, Design Exchange                       100
# Toronto Islands, Harbourfront East, Union Station              100
# University of Toronto, Harbord                                  36
# Victoria Hotel, Commerce Court                                 100
# Victoria Village                                                 5
# Westmount                                                        6
# Weston                                                           2
# Wexford, Maryvale                                                4
# Willowdale South                                                35
# Willowdale West                                                  6
# Willowdale, Newtonbrook                                          1
# Woburn                                                           3
# Woodbine Gardens, Parkview Hill                                 13
# Woodbine Heights                                                 9
# York Mills West                                                  4
# York University, Northwood Park                                  4
#
# [101 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 266 uniques categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                           Neighborhood  Accessories Store  \
# 0                                            Agincourt                0.0
# 1    Bathurst Quay, Harbourfront West, CN Tower, So...                0.0
# 2                                      Bayview Village                0.0
# 3                                          Berczy Park                0.0
# 4    Business Reply Mail Processing Centre 969 Eastern                0.0
# 5                          CFB Toronto, Downsview East                0.0
# 6                          Cabbagetown, St. James Town                0.0
# 7                                  Caledonia-Fairbanks                0.0
# 8                Canada Post Gateway Processing Centre                0.0
# 9                                            Cedarbrae                0.0
# 10                                  Central Bay Street                0.0
# 11          Chinatown, Kensington Market, Grange Park                 0.0
# 12                                            Christie                0.0
# 13                                Church and Wellesley                0.0
# 14                         Cliffside West, Birch Cliff                0.0
# 15     Cliffside, Scarborough Village West, Cliffcrest                0.0
# 16                                          Davisville                0.0
# 17                                    Davisville North                0.0
# 18                                     Don Mills North                0.0
# 19                    Don Mills South, Flemingdon Park                0.0
columns]

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#                        venue  freq
# 0                     Lounge   0.2
# 1             Breakfast Spot   0.2
# 2  Latin American Restaurant   0.2
# 3             Clothing Store   0.2
# 4               Skating Rink   0.2
#
#
# ----Bathurst Quay, Harbourfront West, CN Tower, South Niagara, Railway Lands, King and Spadina, Island airport----
#               venue  freq
# 0   Airport Service  0.19
# 1    Airport Lounge  0.12
# 2  Airport Terminal  0.12
# 3  Sculpture Garden  0.06
# 4           Airport  0.06
#
#
# ----Bayview Village----
#                  venue  freq
# 0                 Café  0.25
# 1                 Bank  0.25
# 2   Chinese Restaurant  0.25
# 3  Japanese Restaurant  0.25
# 4    Accessories Store  0.00
#
#
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1        Cocktail Bar  0.05
# 2         Cheese Shop  0.04
# 3  Seafood Restaurant  0.04
# 4          Steakhouse  0.04
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#                   venue  freq
# 0            Smoke Shop  0.06
# 1         Auto Workshop  0.06
# 2               Brewery  0.06
# 3                  Park  0.06
# 4  Fast Food Restaurant  0.06
#
#
# ----CFB Toronto, Downsview East----
#                         venue  freq
# 0                     Airport  0.25
# 1                        Park  0.25
# 2                 Snack Place  0.25
# 3  Construction & Landscaping  0.25
# 4           Accessories Store  0.00
#
#
# ----Cabbagetown, St. James Town----
#                 venue  freq
# 0          Restaurant  0.07
# 1         Coffee Shop  0.07
# 2              Bakery  0.05
# 3  Italian Restaurant  0.05
# 4         Pizza Place  0.05
#
#
# ----Caledonia-Fairbanks----
#                venue  freq
# 0               Park  0.50
# 1      Women's Store  0.25
# 2             Market  0.25
# 3  Accessories Store  0.00
# 4        Men's Store  0.00
#
#
# ----Canada Post Gateway Processing Centre----
#                  venue  freq
# 0                Hotel  0.17
# 1          Coffee Shop  0.17
# 2        Burrito Place  0.08
# 3  American Restaurant  0.08
# 4  Fried Chicken Joint  0.08
#
#
# ----Cedarbrae----
#                   venue  freq
# 0                Bakery  0.12
# 1           Gas Station  0.12
# 2  Caribbean Restaurant  0.12
# 3       Thai Restaurant  0.12
# 4    Athletics & Sports  0.12
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.17
# 1                Café  0.05
# 2      Ice Cream Shop  0.05
# 3  Italian Restaurant  0.05
# 4      Sandwich Place  0.05
#
#
# ----Chinatown, Kensington Market, Grange Park ----
#                    venue  freq
# 0                    Bar  0.08
# 1                   Café  0.06
# 2     Chinese Restaurant  0.05
# 3  Vietnamese Restaurant  0.05
# 4    Dumpling Restaurant  0.05
#
#
# ----Christie----
#            venue  freq
# 0  Grocery Store  0.22
# 1           Café  0.17
# 2           Park  0.11
# 3    Gas Station  0.06
# 4    Coffee Shop  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1  Japanese Restaurant  0.05
# 2              Gay Bar  0.05
# 3     Sushi Restaurant  0.05
# 4           Restaurant  0.04
#
#
# ----Cliffside West, Birch Cliff----
#                    venue  freq
# 0        College Stadium  0.25
# 1  General Entertainment  0.25
# 2                   Café  0.25
# 3           Skating Rink  0.25
# 4      Martial Arts Dojo  0.00
#
#
# ----Cliffside, Scarborough Village West, Cliffcrest----
#                  venue  freq
# 0                Motel   0.5
# 1  American Restaurant   0.5
# 2               Lounge   0.0
# 3               Market   0.0
# 4    Martial Arts Dojo   0.0
#
#
# ----Davisville----
#             venue  freq
# 0  Sandwich Place  0.09
# 1    Dessert Shop  0.09
# 2     Pizza Place  0.06
# 3            Café  0.06
# 4             Gym  0.06
#
#
# ----Davisville North----
#               venue  freq
# 0              Park  0.14
# 1               Gym  0.14
# 2    Breakfast Spot  0.14
# 3  Department Store  0.14
# 4    Sandwich Place  0.14
#
#
# ----Don Mills North----
#                   venue  freq
# 0  Gym / Fitness Center   0.2
# 1                  Café   0.2
# 2  Caribbean Restaurant   0.2
# 3   Japanese Restaurant   0.2
# 4      Basketball Court   0.2
#
#
# ----Don Mills South, Flemingdon Park----
#                 venue  freq
# 0    Asian Restaurant  0.10
# 1          Beer Store  0.10
# 2                 Gym  0.10
# 3         Coffee Shop  0.10
# 4  Dim Sum Restaurant  0.05
#
#
# ----Dorset Park, Scarborough Town Centre, Wexford Heights----
#                    venue  freq
# 0      Indian Restaurant   0.4
# 1              Pet Store   0.2
# 2  Vietnamese Restaurant   0.2
# 3     Chinese Restaurant   0.2
# 4      Accessories Store   0.0
#
#
# ----Downsview----
#                venue  freq
# 0               Park  0.25
# 1      Grocery Store  0.25
# 2               Bank  0.25
# 3      Shopping Mall  0.25
# 4  Accessories Store  0.00
#
#
# ----Downsview Central----
#                         venue  freq
# 0                Home Service  0.33
# 1              Baseball Field  0.33
# 2                  Food Truck  0.33
# 3         Monument / Landmark  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Downsview North, Bathurst Manor, Wilson Heights----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1      Ice Cream Shop  0.05
# 2  Frozen Yogurt Shop  0.05
# 3          Restaurant  0.05
# 4         Supermarket  0.05
#
#
# ----Downsview Northwest----
#                   venue  freq
# 0  Gym / Fitness Center  0.25
# 1         Grocery Store  0.25
# 2    Athletics & Sports  0.25
# 3          Liquor Store  0.25
# 4     Martial Arts Dojo  0.00
#
#
# ----Dufferin, Dovercourt Village----
#          venue  freq
# 0     Pharmacy  0.11
# 1       Bakery  0.11
# 2  Pizza Place  0.05
# 3         Park  0.05
# 4  Coffee Shop  0.05
#
#
# ----East Birchmount Park, Kennedy Park, Ionview----
#                        venue  freq
# 0           Department Store  0.25
# 1         Chinese Restaurant  0.25
# 2                Coffee Shop  0.25
# 3                 Hobby Shop  0.25
# 4  Middle Eastern Restaurant  0.00
#
#
# ----East Toronto----
#                 venue  freq
# 0                Park  0.33
# 1         Coffee Shop  0.33
# 2   Convenience Store  0.33
# 3   Accessories Store  0.00
# 4  Mexican Restaurant  0.00
#
#
# ----Emery, Humberlea----
#                         venue  freq
# 0              Baseball Field   0.5
# 1  Construction & Landscaping   0.5
# 2           Accessories Store   0.0
# 3               Metro Station   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----First Canadian Place, Underground city----
#           venue  freq
# 0   Coffee Shop  0.13
# 1          Café  0.07
# 2    Steakhouse  0.04
# 3    Restaurant  0.04
# 4  Burger Joint  0.03
#
#
# ----Forest Hill North, Forest Hill West----
#                venue  freq
# 0           Bus Line  0.25
# 1   Sushi Restaurant  0.25
# 2      Jewelry Store  0.25
# 3              Trail  0.25
# 4  Accessories Store  0.00
#
#
# ----Garden District, Ryerson----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1       Clothing Store  0.08
# 2       Cosmetics Shop  0.03
# 3  Japanese Restaurant  0.03
# 4                 Café  0.03
#
#
# ----Glencairn----
#                  venue  freq
# 0          Pizza Place  0.25
# 1  Japanese Restaurant  0.25
# 2                  Pub  0.25
# 3               Bakery  0.25
# 4       Massage Studio  0.00
#
#
# ----Guildwood, Morningside, West Hill----
#                  venue  freq
# 0          Pizza Place  0.14
# 1   Mexican Restaurant  0.14
# 2  Rental Car Location  0.14
# 3       Breakfast Spot  0.14
# 4       Medical Center  0.14
#
#
# ----Highland Creek , Rouge Hill, Port Union----
#                         venue  freq
# 0               Moving Target  0.33
# 1                         Bar  0.33
# 2  Construction & Landscaping  0.33
# 3           Accessories Store  0.00
# 4          Mexican Restaurant  0.00
#
#
# ----Hillcrest Village----
#                       venue  freq
# 0                   Dog Run  0.25
# 1               Golf Course  0.25
# 2                      Pool  0.25
# 3  Mediterranean Restaurant  0.25
# 4         Accessories Store  0.00
#
#
# ----Humber Bay Shores, New Toronto, Mimico South----
#                 venue  freq
# 0           Pet Store  0.08
# 1          Restaurant  0.08
# 2        Liquor Store  0.08
# 3  Seafood Restaurant  0.08
# 4  Mexican Restaurant  0.08
#
#
# ----Humber Summit----
#                  venue  freq
# 0          Pizza Place  0.33
# 1  Empanada Restaurant  0.33
# 2        Shopping Mall  0.33
# 3    Accessories Store  0.00
# 4          Men's Store  0.00
#
#
# ----Humewood-Cedarvale----
#           venue  freq
# 0         Field  0.33
# 1         Trail  0.33
# 2  Hockey Arena  0.33
# 3        Lounge  0.00
# 4        Market  0.00
#
#
# ----Keelesdale, Mount Dennis, Silverthorn, Del Ray----
#             venue  freq
# 0      Restaurant  0.25
# 1    Skating Rink  0.25
# 2             Bar  0.25
# 3  Sandwich Place  0.25
# 4   Metro Station  0.00
#
#
# ----L'Amoreaux West----
#                   venue  freq
# 0  Fast Food Restaurant  0.17
# 1    Chinese Restaurant  0.17
# 2              Pharmacy  0.08
# 3           Coffee Shop  0.08
# 4          Burger Joint  0.08
#
#
# ----Lawrence Heights, Lawrence Manor----
#                     venue  freq
# 0  Furniture / Home Store  0.25
# 1          Clothing Store  0.25
# 2   Vietnamese Restaurant  0.08
# 3                Boutique  0.08
# 4      Miscellaneous Shop  0.08
#
#
# ----Lawrence Manor East, Bedford Park----
#                   venue  freq
# 0  Fast Food Restaurant  0.08
# 1    Italian Restaurant  0.08
# 2           Coffee Shop  0.08
# 3        Sandwich Place  0.08
# 4        Breakfast Spot  0.04
#
#
# ----Lawrence Park----
#                venue  freq
# 0               Park  0.25
# 1               Lake  0.25
# 2        Swim School  0.25
# 3           Bus Line  0.25
# 4  Accessories Store  0.00
#
#
# ----Leaside----
#                     venue  freq
# 0             Coffee Shop  0.09
# 1     Sporting Goods Shop  0.09
# 2  Furniture / Home Store  0.06
# 3            Burger Joint  0.06
# 4        Sushi Restaurant  0.06
#
#
# ----Little Portugal, Trinity–Bellwoods----
#               venue  freq
# 0               Bar  0.12
# 1        Restaurant  0.06
# 2  Asian Restaurant  0.06
# 3       Coffee Shop  0.04
# 4       Pizza Place  0.04
#
#
# ----Long Branch, Alderwood----
#           venue  freq
# 0   Pizza Place  0.22
# 1           Gym  0.11
# 2      Pharmacy  0.11
# 3  Skating Rink  0.11
# 4   Coffee Shop  0.11
#
#
# ----Malvern, Rouge----
#                         venue  freq
# 0        Fast Food Restaurant   0.5
# 1                  Print Shop   0.5
# 2               Metro Station   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
# ----Milliken, Ontario, Agincourt North, L'Amoreaux East, Steeles East----
#                venue  freq
# 0         Playground   0.5
# 1               Park   0.5
# 2  Accessories Store   0.0
# 3        Men's Store   0.0
# 4  Mobile Phone Shop   0.0
#
#
# ----North Midtown, Yorkville, The Annex----
#                            venue  freq
# 0                           Café  0.14
# 1                 Sandwich Place  0.14
# 2                    Coffee Shop  0.10
# 3                       Pharmacy  0.05
# 4  Vegetarian / Vegan Restaurant  0.05
#
#
# ----North Park, Downsview, Upwood Park----
#                         venue  freq
# 0                        Park  0.25
# 1  Construction & Landscaping  0.25
# 2            Basketball Court  0.25
# 3                      Bakery  0.25
# 4           Accessories Store  0.00
#
#
# ----North Toronto West----
#                   venue  freq
# 0        Clothing Store  0.13
# 1           Coffee Shop  0.09
# 2  Gym / Fitness Center  0.04
# 3         Metro Station  0.04
# 4          Dessert Shop  0.04
#
#
# ----Northwest----
#                  venue  freq
# 0  Rental Car Location  0.33
# 1                  Bar  0.33
# 2            Drugstore  0.33
# 3    Accessories Store  0.00
# 4   Mexican Restaurant  0.00
#
#
# ----Oakridge, Golden Mile, Clairlea----
#           venue  freq
# 0        Bakery  0.22
# 1      Bus Line  0.22
# 2  Soccer Field  0.11
# 3   Bus Station  0.11
# 4          Park  0.11
#
#
# ----Old Burnhamthorpe, Markland Wood, Bloordale Gardens, Eringate----
#             venue  freq
# 0  Shopping Plaza  0.11
# 1  Cosmetics Shop  0.11
# 2      Beer Store  0.11
# 3     Coffee Shop  0.11
# 4    Liquor Store  0.11
#
#
# ----Old Mill North, Montgomery Road, The Kingsway----
#                         venue  freq
# 0                       River   0.5
# 1                        Park   0.5
# 2                 Men's Store   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
# ----Old Mill, The Queensway, Fairmont Royal York Hotel, Sunnylea, King's Mill Park, Kingsway Park South East, Mimico, Humber Bay----
#                         venue  freq
# 0              Baseball Field   0.5
# 1                Home Service   0.5
# 2           Accessories Store   0.0
# 3          Mexican Restaurant   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Oriole, Fairview, Henry Farm----
#                   venue  freq
# 0        Clothing Store  0.13
# 1           Coffee Shop  0.08
# 2  Fast Food Restaurant  0.08
# 3            Shoe Store  0.05
# 4   Japanese Restaurant  0.03
#
#
# ----Parkdale Village, Exhibition Place, Brockton----
#             venue  freq
# 0       Nightclub  0.08
# 1     Coffee Shop  0.08
# 2  Breakfast Spot  0.08
# 3            Café  0.08
# 4     Yoga Studio  0.04
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0               Breakfast Spot  0.14
# 1                    Gift Shop  0.14
# 2                  Coffee Shop  0.07
# 3  Eastern European Restaurant  0.07
# 4                Movie Theater  0.07
#
#
# ----Parkwoods----
#                       venue  freq
# 0         Food & Drink Shop   0.5
# 1                      Park   0.5
# 2  Mediterranean Restaurant   0.0
# 3         Mobile Phone Shop   0.0
# 4        Miscellaneous Shop   0.0
#
#
# ----Princess Gardens, Cloverdale, West Deane Park, Martin Grove, Islington----
#                         venue  freq
# 0                 Golf Course   1.0
# 1           Accessories Store   0.0
# 2                 Men's Store   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
# ----Queen's Park ----
#           venue  freq
# 0   Coffee Shop  0.26
# 1           Gym  0.05
# 2          Park  0.05
# 3   Yoga Studio  0.03
# 4  Burger Joint  0.03
#
#
# ----Regent Park----
#          venue  freq
# 0  Coffee Shop  0.17
# 1         Café  0.07
# 2          Pub  0.07
# 3         Park  0.07
# 4       Bakery  0.07
#
#
# ----Richmond, Adelaide, King----
#              venue  freq
# 0      Coffee Shop  0.07
# 1  Thai Restaurant  0.04
# 2       Steakhouse  0.04
# 3             Café  0.04
# 4              Bar  0.04
#
#
# ----Rosedale----
#                venue  freq
# 0               Park  0.50
# 1         Playground  0.25
# 2              Trail  0.25
# 3  Accessories Store  0.00
# 4        Men's Store  0.00
#
#
# ----Roselawn----
#                      venue  freq
# 0                   Garden  0.33
# 1  Health & Beauty Service  0.33
# 2                     Pool  0.33
# 3        Accessories Store  0.00
# 4            Metro Station  0.00
#
#
# ----Royal York South West, South of Bloor, The Queensway, Kingsway Park South West, Mimico----
#             venue  freq
# 0  Hardware Store  0.07
# 1   Tanning Salon  0.07
# 2  Discount Store  0.07
# 3  Sandwich Place  0.07
# 4   Burrito Place  0.07
#
#
# ----Scarborough Village----
#                         venue  freq
# 0                  Playground   1.0
# 1           Accessories Store   0.0
# 2                 Men's Store   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
# ----Silver Hills, York Mills----
#                  venue  freq
# 0    Martial Arts Dojo   0.5
# 1            Cafeteria   0.5
# 2    Accessories Store   0.0
# 3  Monument / Landmark   0.0
# 4               Market   0.0
#
#
# ----Silverstone, Beaumond Heights, Albion Gardens, Mount Olive-Silverstone-Jamestown, Humbergate, South Steeles, Thistletown----
#                  venue  freq
# 0        Grocery Store   0.2
# 1          Pizza Place   0.1
# 2  Fried Chicken Joint   0.1
# 3          Coffee Shop   0.1
# 4       Sandwich Place   0.1
#
#
# ----South Hill, Forest Hill SE, Rathnelly, Deer Park, Summerhill West----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1                  Pub  0.14
# 2  American Restaurant  0.07
# 3         Liquor Store  0.07
# 4          Supermarket  0.07
#
#
# ----St. James Town----
#             venue  freq
# 0     Coffee Shop  0.08
# 1            Café  0.06
# 2      Restaurant  0.05
# 3    Cocktail Bar  0.04
# 4  Breakfast Spot  0.03
#
#
# ----St. Phillips, Martin Grove Gardens, Kingsview Village, Richview Gardens----
#                              venue  freq
# 0                      Pizza Place  0.25
# 1                         Bus Line  0.25
# 2                   Sandwich Place  0.25
# 3                Mobile Phone Shop  0.25
# 4  Molecular Gastronomy Restaurant  0.00
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1                Café  0.04
# 2  Seafood Restaurant  0.03
# 3               Hotel  0.03
# 4          Restaurant  0.03
#
#
# ----Studio District----
#                  venue  freq
# 0                 Café  0.10
# 1          Coffee Shop  0.07
# 2              Brewery  0.05
# 3            Gastropub  0.05
# 4  American Restaurant  0.05
#
#
# ----Sullivan, Clarks Corners, Tam O'Shanter – Sullivan----
#                 venue  freq
# 0         Pizza Place  0.15
# 1  Chinese Restaurant  0.08
# 2            Pharmacy  0.08
# 3                Bank  0.08
# 4   Convenience Store  0.08
#
#
# ----Summerhill East, Moore Park----
#              venue  freq
# 0             Park  0.25
# 1       Playground  0.25
# 2     Tennis Court  0.25
# 3       Restaurant  0.25
# 4  Organic Grocery  0.00
#
#
# ----Swansea, Runnymede----
#                 venue  freq
# 0                Café  0.08
# 1         Coffee Shop  0.08
# 2         Pizza Place  0.08
# 3    Sushi Restaurant  0.05
# 4  Italian Restaurant  0.05
#
#
# ----The Beaches----
#                 venue  freq
# 0   Health Food Store  0.25
# 1                 Pub  0.25
# 2               Trail  0.25
# 3   Accessories Store  0.00
# 4  Mexican Restaurant  0.00
#
#
# ----The Beaches West, India Bazaar----
#               venue  freq
# 0              Park  0.11
# 1         Pet Store  0.06
# 2  Sushi Restaurant  0.06
# 3     Movie Theater  0.06
# 4    Ice Cream Shop  0.06
#
#
# ----The Danforth West, Riverdale----
#                     venue  freq
# 0        Greek Restaurant  0.24
# 1             Coffee Shop  0.10
# 2      Italian Restaurant  0.07
# 3  Furniture / Home Store  0.05
# 4              Restaurant  0.05
#
#
# ----The Junction North, Runnymede----
#                   venue  freq
# 0           Pizza Place  0.25
# 1  Caribbean Restaurant  0.25
# 2         Grocery Store  0.25
# 3               Brewery  0.25
# 4    Mexican Restaurant  0.00
#
#
# ----The Junction South, High Park----
#                 venue  freq
# 0     Thai Restaurant  0.08
# 1                Café  0.08
# 2  Mexican Restaurant  0.08
# 3                 Bar  0.08
# 4                Park  0.04
#
#
# ----Thorncliffe Park----
#                venue  freq
# 0  Indian Restaurant  0.11
# 1        Yoga Studio  0.05
# 2               Bank  0.05
# 3                Gym  0.05
# 4      Grocery Store  0.05
#
#
# ----Toronto Dominion Centre, Design Exchange----
#          venue  freq
# 0  Coffee Shop  0.12
# 1         Café  0.08
# 2        Hotel  0.07
# 3   Steakhouse  0.04
# 4   Restaurant  0.04
#
#
# ----Toronto Islands, Harbourfront East, Union Station ----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1            Aquarium  0.05
# 2  Italian Restaurant  0.04
# 3               Hotel  0.04
# 4                Café  0.04
#
#
# ----University of Toronto, Harbord----
#                  venue  freq
# 0                 Café  0.14
# 1                  Bar  0.06
# 2  Japanese Restaurant  0.06
# 3               Bakery  0.06
# 4            Bookstore  0.06
#
#
# ----Victoria Hotel, Commerce Court----
#            venue  freq
# 0    Coffee Shop  0.12
# 1           Café  0.07
# 2          Hotel  0.06
# 3     Restaurant  0.05
# 4  Deli / Bodega  0.03
#
#
# ----Victoria Village----
#                    venue  freq
# 0            Pizza Place   0.2
# 1            Coffee Shop   0.2
# 2           Intersection   0.2
# 3  Portuguese Restaurant   0.2
# 4           Hockey Arena   0.2
#
#
# ----Westmount----
#                 venue  freq
# 0         Pizza Place  0.17
# 1         Coffee Shop  0.17
# 2        Intersection  0.17
# 3  Chinese Restaurant  0.17
# 4      Sandwich Place  0.17
#
#
# ----Weston----
#                venue  freq
# 0               Park   0.5
# 1  Convenience Store   0.5
# 2  Accessories Store   0.0
# 3        Men's Store   0.0
# 4  Mobile Phone Shop   0.0
#
#
# ----Wexford, Maryvale----
#                        venue  freq
# 0                 Smoke Shop  0.25
# 1             Breakfast Spot  0.25
# 2                     Bakery  0.25
# 3  Middle Eastern Restaurant  0.25
# 4          Accessories Store  0.00
#
#
# ----Willowdale South----
#                  venue  freq
# 0     Ramen Restaurant  0.09
# 1  Japanese Restaurant  0.06
# 2     Sushi Restaurant  0.06
# 3          Pizza Place  0.06
# 4       Sandwich Place  0.06
#
#
# ----Willowdale West----
#             venue  freq
# 0     Pizza Place  0.17
# 1     Coffee Shop  0.17
# 2         Butcher  0.17
# 3  Discount Store  0.17
# 4        Pharmacy  0.17
#
#
# ----Willowdale, Newtonbrook----
#                         venue  freq
# 0                         Gym   1.0
# 1           Accessories Store   0.0
# 2                 Men's Store   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
# ----Woburn----
#                         venue  freq
# 0                 Coffee Shop  0.67
# 1           Korean Restaurant  0.33
# 2           Accessories Store  0.00
# 3               Metro Station  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Woodbine Gardens, Parkview Hill----
#                   venue  freq
# 0           Pizza Place  0.15
# 1  Fast Food Restaurant  0.15
# 2    Athletics & Sports  0.08
# 3             Pet Store  0.08
# 4                  Café  0.08
#
#
# ----Woodbine Heights----
#               venue  freq
# 0              Park  0.11
# 1       Video Store  0.11
# 2  Asian Restaurant  0.11
# 3      Dance Studio  0.11
# 4       Curling Ice  0.11
#
#
# ----York Mills West----
#                venue  freq
# 0               Park  0.50
# 1               Bank  0.25
# 2  Convenience Store  0.25
# 3  Accessories Store  0.00
# 4      Metro Station  0.00
#
#
# ----York University, Northwood Park----
#                   venue  freq
# 0        Massage Studio  0.25
# 1                   Bar  0.25
# 2  Caribbean Restaurant  0.25
# 3           Coffee Shop  0.25
# 4     Accessories Store  0.00

# %% [markdown]
# Let's put that into a pandas dataframe
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood  \
# 0                                          Agincourt
# 1  Bathurst Quay, Harbourfront West, CN Tower, So...
# 2                                    Bayview Village
# 3                                        Berczy Park
# 4  Business Reply Mail Processing Centre 969 Eastern
#
#        1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0  Latin American Restaurant          Skating Rink                Lounge
# 1            Airport Service      Airport Terminal        Airport Lounge
# 2                       Café                  Bank    Chinese Restaurant
# 3                Coffee Shop          Cocktail Bar           Cheese Shop
# 4                       Park                Garden    Light Rail Station
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0        Clothing Store        Breakfast Spot             Drugstore
# 1      Sculpture Garden                   Bar   Rental Car Location
# 2   Japanese Restaurant            Donut Shop                 Diner
# 3            Steakhouse                Bakery                  Café
# 4            Restaurant         Burrito Place         Auto Workshop
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0        Discount Store               Dog Run      Doner Restaurant
# 1           Coffee Shop       Harbor / Marina         Boat or Ferry
# 2        Discount Store               Dog Run      Doner Restaurant
# 3        Farmers Market    Seafood Restaurant              Beer Bar
# 4  Fast Food Restaurant        Farmers Market                   Spa
#
#   10th Most Common Venue
# 0             Donut Shop
# 1           Airport Gate
# 2              Drugstore
# 3           Concert Hall
# 4       Recording Studio

# %% [markdown]
# # Cluster Neighborhoods
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_ 
# to change use .astype()
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 3, 2, 2, 2, 2, 3,
#        2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 3, 2, 2, 2, 0, 2, 2, 2, 3, 2], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.drop(['Cluster Labels'], axis=1 ,inplace = True)
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# check the last columns!
toronto_merged
# Out:
#     Postcode                 Borough  \
# 0        M3A              North York
# 1        M4A              North York
# 2        M5A        Downtown Toronto
# 3        M6A              North York
# 4        M7A        Downtown Toronto
# 5        M9A  Queen's Park (Toronto)
# 6        M1B    Scarborough, Toronto
# 7        M3B              North York
# 8        M4B               East York
# 9        M5B        Downtown Toronto
# 10       M6B              North York
# 11       M9B               Etobicoke
# 12       M1C    Scarborough, Toronto
# 13       M3C              North York
# 14       M4C               East York
# 15       M5C        Downtown Toronto
# 16       M6C                    York
# 17       M9C               Etobicoke
# 18       M1E    Scarborough, Toronto
# 19       M4E            East Toronto
# 20       M5E        Downtown Toronto
# 21       M6E                    York
# 22       M1G    Scarborough, Toronto
# 23       M4G               East York
# 24       M5G        Downtown Toronto
# 25       M6G        Downtown Toronto
# 26       M1H    Scarborough, Toronto
# 27       M2H              North York
# 28       M3H              North York
# 29       M4H               East York
# ..       ...                     ...
# 73       M4R         Central Toronto
# 74       M5R         Central Toronto
# 75       M6R            West Toronto
# 76       M7R             Mississauga
# 77       M9R               Etobicoke
# 78       M1S    Scarborough, Toronto
# 79       M4S         Central Toronto
# 80       M5S        Downtown Toronto
# 81       M6S            West Toronto
# 82       M1T    Scarborough, Toronto
# 83       M4T         Central Toronto
# 84       M5T        Downtown Toronto
# 85       M1V    Scarborough, Toronto
# 86       M4V         Central Toronto
# 87       M5V        Downtown Toronto
# 88       M8V               Etobicoke
# 89       M9V               Etobicoke
# 90       M1W    Scarborough, Toronto
# 91       M4W        Downtown Toronto
# 92       M5W        Downtown Toronto
# 93       M8W               Etobicoke
# 94       M9W               Etobicoke
# 95       M1X    Scarborough, Toronto
# 96       M4X        Downtown Toronto
# 97       M5X        Downtown Toronto
# 98       M8X               Etobicoke
# 99       M4Y        Downtown Toronto
# 100      M7Y            East Toronto
# 101      M8Y               Etobicoke
# 102      M8Z               Etobicoke
#
#                                           Neighborhood   Latitude  Longitude  \
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                                          Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                        Queen's Park   43.662301 -79.389494
# 5                                        Queen's Park   43.667856 -79.532242
# 6                                       Malvern, Rouge  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Garden District, Ryerson  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Princess Gardens, Cloverdale, West Deane Park,...  43.650943 -79.554724
# 12             Highland Creek , Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Don Mills South, Flemingdon Park  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Old Burnhamthorpe, Markland Wood, Bloordale Ga...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Downsview North, Bathurst Manor, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 North Midtown, Yorkville, The Annex  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   St. Phillips, Martin Grove Gardens, Kingsview ...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      University of Toronto, Harbord  43.662696 -79.400049
# 81                                  Swansea, Runnymede  43.651571 -79.484450
# 82   Sullivan, Clarks Corners, Tam O'Shanter – Sull...  43.781638 -79.304302
# 83                         Summerhill East, Moore Park  43.689574 -79.383160
# 84          Chinatown, Kensington Market, Grange Park   43.653206 -79.400049
# 85   Milliken, Ontario, Agincourt North, L'Amoreaux...  43.815252 -79.284577
# 86   South Hill, Forest Hill SE, Rathnelly, Deer Pa...  43.686412 -79.400049
# 87   Bathurst Quay, Harbourfront West, CN Tower, So...  43.628947 -79.394420
# 88        Humber Bay Shores, New Toronto, Mimico South  43.605647 -79.501321
# 89   Silverstone, Beaumond Heights, Albion Gardens,...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Long Branch, Alderwood  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       Old Mill North, Montgomery Road, The Kingsway  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Old Mill, The Queensway, Fairmont Royal York H...  43.636258 -79.498509
# 102  Royal York South West, South of Bloor, The Que...  43.628841 -79.520999
#
#      Cluster Labels      1st Most Common Venue       2nd Most Common Venue  \
# 0               3.0                       Park           Food & Drink Shop
# 1               2.0      Portuguese Restaurant                 Coffee Shop
# 2               2.0                Coffee Shop                      Bakery
# 3               2.0     Furniture / Home Store              Clothing Store
# 4               2.0                Coffee Shop                        Park
# 5               2.0                Coffee Shop                        Park
# 6               2.0       Fast Food Restaurant                  Print Shop
# 7               2.0       Gym / Fitness Center        Caribbean Restaurant
# 8               2.0                Pizza Place        Fast Food Restaurant
# 9               2.0                Coffee Shop              Clothing Store
# 10              2.0                     Bakery                 Pizza Place
# 11              2.0                Golf Course                 Yoga Studio
# 12              2.0                        Bar  Construction & Landscaping
# 13              2.0                        Gym                 Coffee Shop
# 14              2.0                Curling Ice                 Video Store
# 15              2.0                Coffee Shop                        Café
# 16              2.0                      Trail                       Field
# 17              2.0          Convenience Store                        Park
# 18              2.0          Electronics Store              Breakfast Spot
# 19              2.0                      Trail                         Pub
# 20              2.0                Coffee Shop                Cocktail Bar
# 21              3.0                       Park               Women's Store
# 22              2.0                Coffee Shop           Korean Restaurant
# 23              2.0        Sporting Goods Shop                 Coffee Shop
# 24              2.0                Coffee Shop              Sandwich Place
# 25              2.0              Grocery Store                        Café
# 26              2.0                     Bakery                 Gas Station
# 27              2.0   Mediterranean Restaurant                 Golf Course
# 28              2.0                Coffee Shop            Sushi Restaurant
# 29              2.0          Indian Restaurant                 Yoga Studio
# ..              ...                        ...                         ...
# 73              2.0             Clothing Store                 Coffee Shop
# 74              2.0                       Café              Sandwich Place
# 75              2.0             Breakfast Spot                   Gift Shop
# 76              2.0                      Hotel                 Coffee Shop
# 77              2.0          Mobile Phone Shop                    Bus Line
# 78              2.0  Latin American Restaurant                Skating Rink
# 79              2.0             Sandwich Place                Dessert Shop
# 80              2.0                       Café                   Bookstore
# 81              2.0                       Café                 Pizza Place
# 82              2.0                Pizza Place               Shopping Mall
# 83              3.0                       Park                  Playground
# 84              2.0                        Bar                        Café
# 85              3.0                       Park                  Playground
# 86              2.0                        Pub                 Coffee Shop
# 87              2.0            Airport Service            Airport Terminal
# 88              2.0         Mexican Restaurant                Liquor Store
# 89              2.0              Grocery Store                 Pizza Place
# 90              2.0         Chinese Restaurant        Fast Food Restaurant
# 91              3.0                       Park                       Trail
# 92              2.0                Coffee Shop                        Café
# 93              2.0                Pizza Place              Sandwich Place
# 94              2.0                  Drugstore                         Bar
# 95              NaN                        NaN                         NaN
# 96              2.0                Coffee Shop                  Restaurant
# 97              2.0                Coffee Shop                        Café
# 98              3.0                       Park                       River
# 99              2.0                Coffee Shop            Sushi Restaurant
# 100             2.0                       Park                      Garden
# 101             2.0               Home Service              Baseball Field
# 102             2.0       Fast Food Restaurant              Hardware Store
#
#     3rd Most Common Venue          4th Most Common Venue  \
# 0        Department Store           Ethiopian Restaurant
# 1             Pizza Place                   Intersection
# 2                     Pub                           Café
# 3       Accessories Store          Vietnamese Restaurant
# 4                     Gym                    Yoga Studio
# 5                     Gym                    Yoga Studio
# 6             Yoga Studio                     Donut Shop
# 7     Japanese Restaurant               Basketball Court
# 8    Gym / Fitness Center                      Gastropub
# 9          Cosmetics Shop            Japanese Restaurant
# 10                    Pub            Japanese Restaurant
# 11             Donut Shop                   Dessert Shop
# 12          Moving Target                    Yoga Studio
# 13             Beer Store               Asian Restaurant
# 14             Beer Store                   Dance Studio
# 15             Restaurant                   Cocktail Bar
# 16           Hockey Arena                    Yoga Studio
# 17         Shopping Plaza                   Liquor Store
# 18            Pizza Place             Mexican Restaurant
# 19      Health Food Store                    Yoga Studio
# 20            Cheese Shop                     Steakhouse
# 21                 Market                     Donut Shop
# 22            Yoga Studio                      Drugstore
# 23       Sushi Restaurant                   Burger Joint
# 24     Italian Restaurant                           Café
# 25                   Park                    Gas Station
# 26    Fried Chicken Joint               Hakka Restaurant
# 27                Dog Run                           Pool
# 28               Pharmacy                  Deli / Bodega
# 29                   Bank                  Grocery Store
# ..                    ...                            ...
# 73            Yoga Studio                  Grocery Store
# 74            Coffee Shop                    Pizza Place
# 75           Dessert Shop               Cuban Restaurant
# 76    American Restaurant      Middle Eastern Restaurant
# 77            Pizza Place                 Sandwich Place
# 78                 Lounge                 Clothing Store
# 79                   Café                            Gym
# 80                    Bar            Japanese Restaurant
# 81            Coffee Shop               Sushi Restaurant
# 82            Gas Station            Fried Chicken Joint
# 83           Tennis Court                     Restaurant
# 84    Dumpling Restaurant  Vegetarian / Vegan Restaurant
# 85       Doner Restaurant               Department Store
# 86    American Restaurant               Sushi Restaurant
# 87         Airport Lounge               Sculpture Garden
# 88                    Gym             Seafood Restaurant
# 89           Liquor Store           Fast Food Restaurant
# 90          Grocery Store                 Breakfast Spot
# 91             Playground                   Dessert Shop
# 92     Seafood Restaurant            Japanese Restaurant
# 93            Coffee Shop                            Gym
# 94    Rental Car Location           Ethiopian Restaurant
# 95                    NaN                            NaN
# 96                    Pub                           Café
# 97             Steakhouse                     Restaurant
# 98          Deli / Bodega            Empanada Restaurant
# 99    Japanese Restaurant                        Gay Bar
# 100    Light Rail Station                     Restaurant
# 101           Yoga Studio                     Donut Shop
# 102       Supplement Shop                 Discount Store
#
#         5th Most Common Venue        6th Most Common Venue  \
# 0         Empanada Restaurant            Electronics Store
# 1                Hockey Arena             Doner Restaurant
# 2                        Park                   Restaurant
# 3                 Event Space           Miscellaneous Shop
# 4                         Bar        Portuguese Restaurant
# 5                         Bar        Portuguese Restaurant
# 6          Dim Sum Restaurant                        Diner
# 7                        Café   Construction & Landscaping
# 8          Athletics & Sports                 Intersection
# 9                        Café                        Diner
# 10                 Donut Shop           Dim Sum Restaurant
# 11         Dim Sum Restaurant                        Diner
# 12                 Donut Shop                        Diner
# 13        Japanese Restaurant           Chinese Restaurant
# 14           Asian Restaurant               Cosmetics Shop
# 15             Clothing Store                        Hotel
# 16         Dim Sum Restaurant                        Diner
# 17                Coffee Shop                  Pizza Place
# 18        Rental Car Location                 Intersection
# 19               Dessert Shop           Dim Sum Restaurant
# 20                     Bakery                         Café
# 21         Dim Sum Restaurant                        Diner
# 22                      Diner               Discount Store
# 23     Furniture / Home Store            Fish & Chips Shop
# 24             Ice Cream Shop                    Juice Bar
# 25         Italian Restaurant                        Diner
# 26       Caribbean Restaurant           Athletics & Sports
# 27                Yoga Studio                 Dessert Shop
# 28                       Bank                  Supermarket
# 29                        Gym                  Gas Station
# ..                        ...                          ...
# 73         Salon / Barbershop                   Restaurant
# 74                        Pub            Indian Restaurant
# 75                        Bar                    Bookstore
# 76   Mediterranean Restaurant                 Intersection
# 77           Doner Restaurant           Dim Sum Restaurant
# 78             Breakfast Spot                    Drugstore
# 79                Coffee Shop           Italian Restaurant
# 80             Sandwich Place                   Restaurant
# 81                 Restaurant           Italian Restaurant
# 82         Italian Restaurant              Thai Restaurant
# 83        Dumpling Restaurant                    Drugstore
# 84         Chinese Restaurant                  Coffee Shop
# 85               Dessert Shop           Dim Sum Restaurant
# 86        Fried Chicken Joint                   Sports Bar
# 87                        Bar          Rental Car Location
# 88                     Bakery                    Pet Store
# 89                 Beer Store               Sandwich Place
# 90                   Gym Pool                  Coffee Shop
# 91         Dim Sum Restaurant                        Diner
# 92         Italian Restaurant                 Cocktail Bar
# 93               Skating Rink                          Pub
# 94        Empanada Restaurant            Electronics Store
# 95                        NaN                          NaN
# 96                     Bakery           Italian Restaurant
# 97         Seafood Restaurant                    Gastropub
# 98          Electronics Store  Eastern European Restaurant
# 99                 Restaurant                          Pub
# 100             Burrito Place                Auto Workshop
# 101                     Diner               Discount Store
# 102             Tanning Salon                  Flower Shop
#
#            7th Most Common Venue 8th Most Common Venue  \
# 0    Eastern European Restaurant   Dumpling Restaurant
# 1             Dim Sum Restaurant                 Diner
# 2                 Breakfast Spot    Mexican Restaurant
# 3                    Coffee Shop              Boutique
# 4                           Café                 Diner
# 5                           Café                 Diner
# 6                 Discount Store               Dog Run
# 7              Convenience Store           Event Space
# 8                       Bus Line                  Bank
# 9               Ramen Restaurant        Lingerie Store
# 10                         Diner        Discount Store
# 11                Discount Store               Dog Run
# 12                Discount Store               Dog Run
# 13                   Supermarket            Restaurant
# 14                  Skating Rink              Pharmacy
# 15                      Beer Bar   American Restaurant
# 16                Discount Store               Dog Run
# 17                          Café            Beer Store
# 18                Medical Center           Yoga Studio
# 19                         Diner        Discount Store
# 20                Farmers Market    Seafood Restaurant
# 21                Discount Store               Dog Run
# 22                       Dog Run      Doner Restaurant
# 23                          Bank             Juice Bar
# 24           Japanese Restaurant          Burger Joint
# 25                    Restaurant           Candy Store
# 26               Thai Restaurant                  Bank
# 27            Dim Sum Restaurant                 Diner
# 28     Middle Eastern Restaurant            Restaurant
# 29          Fast Food Restaurant          Liquor Store
# ..                           ...                   ...
# 73           Rental Car Location                  Park
# 74     Middle Eastern Restaurant             BBQ Joint
# 75                       Dog Run    Italian Restaurant
# 76                 Burrito Place   Fried Chicken Joint
# 77                         Diner        Discount Store
# 78                Discount Store               Dog Run
# 79                   Pizza Place      Sushi Restaurant
# 80                        Bakery    Chinese Restaurant
# 81                           Bar          Dessert Shop
# 82            Chinese Restaurant  Fast Food Restaurant
# 83   Eastern European Restaurant            Donut Shop
# 84         Vietnamese Restaurant    Mexican Restaurant
# 85                         Diner        Discount Store
# 86                    Restaurant           Supermarket
# 87                   Coffee Shop       Harbor / Marina
# 88                      Pharmacy           Pizza Place
# 89           Fried Chicken Joint           Coffee Shop
# 90                      Pharmacy           Pizza Place
# 91                Discount Store               Dog Run
# 92                         Hotel            Restaurant
# 93                      Pharmacy                  Pool
# 94   Eastern European Restaurant   Dumpling Restaurant
# 95                           NaN                   NaN
# 96                   Pizza Place   Japanese Restaurant
# 97                           Bar      Asian Restaurant
# 98           Dumpling Restaurant             Drugstore
# 99                          Café                 Hotel
# 100         Fast Food Restaurant        Farmers Market
# 101                      Dog Run      Doner Restaurant
# 102                Burrito Place          Burger Joint
#
#          9th Most Common Venue       10th Most Common Venue
# 0                    Drugstore                   Donut Shop
# 1               Discount Store                      Dog Run
# 2                  Yoga Studio            French Restaurant
# 3            Electronics Store  Eastern European Restaurant
# 4                     Beer Bar         Fast Food Restaurant
# 5                     Beer Bar         Fast Food Restaurant
# 6             Doner Restaurant                    Drugstore
# 7         Ethiopian Restaurant          Empanada Restaurant
# 8                         Café                     Pharmacy
# 9    Middle Eastern Restaurant                   Restaurant
# 10                     Dog Run             Doner Restaurant
# 11            Doner Restaurant                    Drugstore
# 12            Doner Restaurant                    Drugstore
# 13          Dim Sum Restaurant          Sporting Goods Shop
# 14                        Park      Comfort Food Restaurant
# 15              Cosmetics Shop               Breakfast Spot
# 16            Doner Restaurant                   Donut Shop
# 17              Cosmetics Shop             Doner Restaurant
# 18                     Dog Run           Dim Sum Restaurant
# 19                     Dog Run             Doner Restaurant
# 20                    Beer Bar                 Concert Hall
# 21            Doner Restaurant          Dumpling Restaurant
# 22                  Donut Shop  Eastern European Restaurant
# 23                Dessert Shop                   Sports Bar
# 24            Department Store                  Salad Place
# 25          Athletics & Sports                   Baby Store
# 26                Dessert Shop           Dim Sum Restaurant
# 27              Discount Store             Doner Restaurant
# 28                       Diner           Chinese Restaurant
# 29              Discount Store    Middle Eastern Restaurant
# ..                         ...                          ...
# 73          Mexican Restaurant                Metro Station
# 74              History Museum                 Burger Joint
# 75               Movie Theater                   Restaurant
# 76                         Gym               Sandwich Place
# 77                     Dog Run                   Donut Shop
# 78            Doner Restaurant                   Donut Shop
# 79                     Brewery             Asian Restaurant
# 80                 Coffee Shop                Poutine Place
# 81                 Fish Market            Fish & Chips Shop
# 82           Convenience Store                     Pharmacy
# 83            Doner Restaurant                 Dance Studio
# 84                  Donut Shop                Grocery Store
# 85                     Dog Run                   Donut Shop
# 86                 Pizza Place                 Liquor Store
# 87               Boat or Ferry                 Airport Gate
# 88                  Restaurant                         Café
# 89                    Pharmacy                   Comic Shop
# 90              Sandwich Place                 Burger Joint
# 91            Doner Restaurant                   Donut Shop
# 92                    Beer Bar               Breakfast Spot
# 93                 Yoga Studio                 Dessert Shop
# 94                Dessert Shop                   Donut Shop
# 95                         NaN                          NaN
# 96                       Diner                      Butcher
# 97                         Gym                        Hotel
# 98                  Donut Shop             Doner Restaurant
# 99    Mediterranean Restaurant                  Men's Store
# 100                        Spa             Recording Studio
# 101                  Drugstore                 Dessert Shop
# 102          Convenience Store                       Bakery
#
# [103 rows x 16 columns]

# %% [markdown]
# 5. Examine Clusters
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                  Borough  Cluster Labels 1st Most Common Venue  \
# 32  Scarborough, Toronto             1.0            Playground
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 32           Yoga Studio            Donut Shop          Dessert Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 32    Dim Sum Restaurant                 Diner        Discount Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 32               Dog Run      Doner Restaurant              Drugstore

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                  Borough  Cluster Labels 1st Most Common Venue  \
# 32  Scarborough, Toronto             1.0            Playground
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 32           Yoga Studio            Donut Shop          Dessert Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 32    Dim Sum Restaurant                 Diner        Discount Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 32               Dog Run      Doner Restaurant              Drugstore

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                     Borough  Cluster Labels      1st Most Common Venue  \
# 1                North York             2.0      Portuguese Restaurant
# 2          Downtown Toronto             2.0                Coffee Shop
# 3                North York             2.0     Furniture / Home Store
# 4          Downtown Toronto             2.0                Coffee Shop
# 5    Queen's Park (Toronto)             2.0                Coffee Shop
# 6      Scarborough, Toronto             2.0       Fast Food Restaurant
# 7                North York             2.0       Gym / Fitness Center
# 8                 East York             2.0                Pizza Place
# 9          Downtown Toronto             2.0                Coffee Shop
# 10               North York             2.0                     Bakery
# 11                Etobicoke             2.0                Golf Course
# 12     Scarborough, Toronto             2.0                        Bar
# 13               North York             2.0                        Gym
# 14                East York             2.0                Curling Ice
# 15         Downtown Toronto             2.0                Coffee Shop
# 16                     York             2.0                      Trail
# 17                Etobicoke             2.0          Convenience Store
# 18     Scarborough, Toronto             2.0          Electronics Store
# 19             East Toronto             2.0                      Trail
# 20         Downtown Toronto             2.0                Coffee Shop
# 22     Scarborough, Toronto             2.0                Coffee Shop
# 23                East York             2.0        Sporting Goods Shop
# 24         Downtown Toronto             2.0                Coffee Shop
# 25         Downtown Toronto             2.0              Grocery Store
# 26     Scarborough, Toronto             2.0                     Bakery
# 27               North York             2.0   Mediterranean Restaurant
# 28               North York             2.0                Coffee Shop
# 29                East York             2.0          Indian Restaurant
# 30         Downtown Toronto             2.0                Coffee Shop
# 31             West Toronto             2.0                     Bakery
# ..                      ...             ...                        ...
# 68          Central Toronto             2.0                      Trail
# 69             West Toronto             2.0            Thai Restaurant
# 70                Etobicoke             2.0         Chinese Restaurant
# 71     Scarborough, Toronto             2.0  Middle Eastern Restaurant
# 72               North York             2.0                    Butcher
# 73          Central Toronto             2.0             Clothing Store
# 74          Central Toronto             2.0                       Café
# 75             West Toronto             2.0             Breakfast Spot
# 76              Mississauga             2.0                      Hotel
# 77                Etobicoke             2.0          Mobile Phone Shop
# 78     Scarborough, Toronto             2.0  Latin American Restaurant
# 79          Central Toronto             2.0             Sandwich Place
# 80         Downtown Toronto             2.0                       Café
# 81             West Toronto             2.0                       Café
# 82     Scarborough, Toronto             2.0                Pizza Place
# 84         Downtown Toronto             2.0                        Bar
# 86          Central Toronto             2.0                        Pub
# 87         Downtown Toronto             2.0            Airport Service
# 88                Etobicoke             2.0         Mexican Restaurant
# 89                Etobicoke             2.0              Grocery Store
# 90     Scarborough, Toronto             2.0         Chinese Restaurant
# 92         Downtown Toronto             2.0                Coffee Shop
# 93                Etobicoke             2.0                Pizza Place
# 94                Etobicoke             2.0                  Drugstore
# 96         Downtown Toronto             2.0                Coffee Shop
# 97         Downtown Toronto             2.0                Coffee Shop
# 99         Downtown Toronto             2.0                Coffee Shop
# 100            East Toronto             2.0                       Park
# 101               Etobicoke             2.0               Home Service
# 102               Etobicoke             2.0       Fast Food Restaurant
#
#           2nd Most Common Venue 3rd Most Common Venue  \
# 1                   Coffee Shop           Pizza Place
# 2                        Bakery                   Pub
# 3                Clothing Store     Accessories Store
# 4                          Park                   Gym
# 5                          Park                   Gym
# 6                    Print Shop           Yoga Studio
# 7          Caribbean Restaurant   Japanese Restaurant
# 8          Fast Food Restaurant  Gym / Fitness Center
# 9                Clothing Store        Cosmetics Shop
# 10                  Pizza Place                   Pub
# 11                  Yoga Studio            Donut Shop
# 12   Construction & Landscaping         Moving Target
# 13                  Coffee Shop            Beer Store
# 14                  Video Store            Beer Store
# 15                         Café            Restaurant
# 16                        Field          Hockey Arena
# 17                         Park        Shopping Plaza
# 18               Breakfast Spot           Pizza Place
# 19                          Pub     Health Food Store
# 20                 Cocktail Bar           Cheese Shop
# 22            Korean Restaurant           Yoga Studio
# 23                  Coffee Shop      Sushi Restaurant
# 24               Sandwich Place    Italian Restaurant
# 25                         Café                  Park
# 26                  Gas Station   Fried Chicken Joint
# 27                  Golf Course               Dog Run
# 28             Sushi Restaurant              Pharmacy
# 29                  Yoga Studio                  Bank
# 30              Thai Restaurant                  Café
# 31                     Pharmacy  Gym / Fitness Center
# ..                          ...                   ...
# 68             Sushi Restaurant         Jewelry Store
# 69                          Bar    Mexican Restaurant
# 70    Middle Eastern Restaurant           Coffee Shop
# 71                       Bakery        Breakfast Spot
# 72                Grocery Store              Pharmacy
# 73                  Coffee Shop           Yoga Studio
# 74               Sandwich Place           Coffee Shop
# 75                    Gift Shop          Dessert Shop
# 76                  Coffee Shop   American Restaurant
# 77                     Bus Line           Pizza Place
# 78                 Skating Rink                Lounge
# 79                 Dessert Shop                  Café
# 80                    Bookstore                   Bar
# 81                  Pizza Place           Coffee Shop
# 82                Shopping Mall           Gas Station
# 84                         Café   Dumpling Restaurant
# 86                  Coffee Shop   American Restaurant
# 87             Airport Terminal        Airport Lounge
# 88                 Liquor Store                   Gym
# 89                  Pizza Place          Liquor Store
# 90         Fast Food Restaurant         Grocery Store
# 92                         Café    Seafood Restaurant
# 93               Sandwich Place           Coffee Shop
# 94                          Bar   Rental Car Location
# 96                   Restaurant                   Pub
# 97                         Café            Steakhouse
# 99             Sushi Restaurant   Japanese Restaurant
# 100                      Garden    Light Rail Station
# 101              Baseball Field           Yoga Studio
# 102              Hardware Store       Supplement Shop
#
#              4th Most Common Venue     5th Most Common Venue  \
# 1                     Intersection              Hockey Arena
# 2                             Café                      Park
# 3            Vietnamese Restaurant               Event Space
# 4                      Yoga Studio                       Bar
# 5                      Yoga Studio                       Bar
# 6                       Donut Shop        Dim Sum Restaurant
# 7                 Basketball Court                      Café
# 8                        Gastropub        Athletics & Sports
# 9              Japanese Restaurant                      Café
# 10             Japanese Restaurant                Donut Shop
# 11                    Dessert Shop        Dim Sum Restaurant
# 12                     Yoga Studio                Donut Shop
# 13                Asian Restaurant       Japanese Restaurant
# 14                    Dance Studio          Asian Restaurant
# 15                    Cocktail Bar            Clothing Store
# 16                     Yoga Studio        Dim Sum Restaurant
# 17                    Liquor Store               Coffee Shop
# 18              Mexican Restaurant       Rental Car Location
# 19                     Yoga Studio              Dessert Shop
# 20                      Steakhouse                    Bakery
# 22                       Drugstore                     Diner
# 23                    Burger Joint    Furniture / Home Store
# 24                            Café            Ice Cream Shop
# 25                     Gas Station        Italian Restaurant
# 26                Hakka Restaurant      Caribbean Restaurant
# 27                            Pool               Yoga Studio
# 28                   Deli / Bodega                      Bank
# 29                   Grocery Store                       Gym
# 30                      Steakhouse                       Bar
# 31                   Grocery Store      Fast Food Restaurant
# ..                             ...                       ...
# 68                        Bus Line               Yoga Studio
# 69                            Café    Furniture / Home Store
# 70                     Pizza Place              Intersection
# 71                      Smoke Shop               Yoga Studio
# 72                     Pizza Place               Coffee Shop
# 73                   Grocery Store        Salon / Barbershop
# 74                     Pizza Place                       Pub
# 75                Cuban Restaurant                       Bar
# 76       Middle Eastern Restaurant  Mediterranean Restaurant
# 77                  Sandwich Place          Doner Restaurant
# 78                  Clothing Store            Breakfast Spot
# 79                             Gym               Coffee Shop
# 80             Japanese Restaurant            Sandwich Place
# 81                Sushi Restaurant                Restaurant
# 82             Fried Chicken Joint        Italian Restaurant
# 84   Vegetarian / Vegan Restaurant        Chinese Restaurant
# 86                Sushi Restaurant       Fried Chicken Joint
# 87                Sculpture Garden                       Bar
# 88              Seafood Restaurant                    Bakery
# 89            Fast Food Restaurant                Beer Store
# 90                  Breakfast Spot                  Gym Pool
# 92             Japanese Restaurant        Italian Restaurant
# 93                             Gym              Skating Rink
# 94            Ethiopian Restaurant       Empanada Restaurant
# 96                            Café                    Bakery
# 97                      Restaurant        Seafood Restaurant
# 99                         Gay Bar                Restaurant
# 100                     Restaurant             Burrito Place
# 101                     Donut Shop                     Diner
# 102                 Discount Store             Tanning Salon
#
#           6th Most Common Venue        7th Most Common Venue  \
# 1              Doner Restaurant           Dim Sum Restaurant
# 2                    Restaurant               Breakfast Spot
# 3            Miscellaneous Shop                  Coffee Shop
# 4         Portuguese Restaurant                         Café
# 5         Portuguese Restaurant                         Café
# 6                         Diner               Discount Store
# 7    Construction & Landscaping            Convenience Store
# 8                  Intersection                     Bus Line
# 9                         Diner             Ramen Restaurant
# 10           Dim Sum Restaurant                        Diner
# 11                        Diner               Discount Store
# 12                        Diner               Discount Store
# 13           Chinese Restaurant                  Supermarket
# 14               Cosmetics Shop                 Skating Rink
# 15                        Hotel                     Beer Bar
# 16                        Diner               Discount Store
# 17                  Pizza Place                         Café
# 18                 Intersection               Medical Center
# 19           Dim Sum Restaurant                        Diner
# 20                         Café               Farmers Market
# 22               Discount Store                      Dog Run
# 23            Fish & Chips Shop                         Bank
# 24                    Juice Bar          Japanese Restaurant
# 25                        Diner                   Restaurant
# 26           Athletics & Sports              Thai Restaurant
# 27                 Dessert Shop           Dim Sum Restaurant
# 28                  Supermarket    Middle Eastern Restaurant
# 29                  Gas Station         Fast Food Restaurant
# 30               Breakfast Spot                 Burger Joint
# 31    Middle Eastern Restaurant                  Music Venue
# ..                          ...                          ...
# 68                        Diner               Discount Store
# 69           Italian Restaurant                    Speakeasy
# 70               Sandwich Place                  Yoga Studio
# 71             Doner Restaurant                        Diner
# 72               Discount Store                      Dog Run
# 73                   Restaurant          Rental Car Location
# 74            Indian Restaurant    Middle Eastern Restaurant
# 75                    Bookstore                      Dog Run
# 76                 Intersection                Burrito Place
# 77           Dim Sum Restaurant                        Diner
# 78                    Drugstore               Discount Store
# 79           Italian Restaurant                  Pizza Place
# 80                   Restaurant                       Bakery
# 81           Italian Restaurant                          Bar
# 82              Thai Restaurant           Chinese Restaurant
# 84                  Coffee Shop        Vietnamese Restaurant
# 86                   Sports Bar                   Restaurant
# 87          Rental Car Location                  Coffee Shop
# 88                    Pet Store                     Pharmacy
# 89               Sandwich Place          Fried Chicken Joint
# 90                  Coffee Shop                     Pharmacy
# 92                 Cocktail Bar                        Hotel
# 93                          Pub                     Pharmacy
# 94            Electronics Store  Eastern European Restaurant
# 96           Italian Restaurant                  Pizza Place
# 97                    Gastropub                          Bar
# 99                          Pub                         Café
# 100               Auto Workshop         Fast Food Restaurant
# 101              Discount Store                      Dog Run
# 102                 Flower Shop                Burrito Place
#
#     8th Most Common Venue      9th Most Common Venue  \
# 1                   Diner             Discount Store
# 2      Mexican Restaurant                Yoga Studio
# 3                Boutique          Electronics Store
# 4                   Diner                   Beer Bar
# 5                   Diner                   Beer Bar
# 6                 Dog Run           Doner Restaurant
# 7             Event Space       Ethiopian Restaurant
# 8                    Bank                       Café
# 9          Lingerie Store  Middle Eastern Restaurant
# 10         Discount Store                    Dog Run
# 11                Dog Run           Doner Restaurant
# 12                Dog Run           Doner Restaurant
# 13             Restaurant         Dim Sum Restaurant
# 14               Pharmacy                       Park
# 15    American Restaurant             Cosmetics Shop
# 16                Dog Run           Doner Restaurant
# 17             Beer Store             Cosmetics Shop
# 18            Yoga Studio                    Dog Run
# 19         Discount Store                    Dog Run
# 20     Seafood Restaurant                   Beer Bar
# 22       Doner Restaurant                 Donut Shop
# 23              Juice Bar               Dessert Shop
# 24           Burger Joint           Department Store
# 25            Candy Store         Athletics & Sports
# 26                   Bank               Dessert Shop
# 27                  Diner             Discount Store
# 28             Restaurant                      Diner
# 29           Liquor Store             Discount Store
# 30                 Bakery                 Restaurant
# 31            Coffee Shop                Pizza Place
# ..                    ...                        ...
# 68                Dog Run           Doner Restaurant
# 69             Steakhouse              Grocery Store
# 70     Dim Sum Restaurant                      Diner
# 71         Discount Store                    Dog Run
# 72       Department Store               Dessert Shop
# 73                   Park         Mexican Restaurant
# 74              BBQ Joint             History Museum
# 75     Italian Restaurant              Movie Theater
# 76    Fried Chicken Joint                        Gym
# 77         Discount Store                    Dog Run
# 78                Dog Run           Doner Restaurant
# 79       Sushi Restaurant                    Brewery
# 80     Chinese Restaurant                Coffee Shop
# 81           Dessert Shop                Fish Market
# 82   Fast Food Restaurant          Convenience Store
# 84     Mexican Restaurant                 Donut Shop
# 86            Supermarket                Pizza Place
# 87        Harbor / Marina              Boat or Ferry
# 88            Pizza Place                 Restaurant
# 89            Coffee Shop                   Pharmacy
# 90            Pizza Place             Sandwich Place
# 92             Restaurant                   Beer Bar
# 93                   Pool                Yoga Studio
# 94    Dumpling Restaurant               Dessert Shop
# 96    Japanese Restaurant                      Diner
# 97       Asian Restaurant                        Gym
# 99                  Hotel   Mediterranean Restaurant
# 100        Farmers Market                        Spa
# 101      Doner Restaurant                  Drugstore
# 102          Burger Joint          Convenience Store
#
#           10th Most Common Venue
# 1                        Dog Run
# 2              French Restaurant
# 3    Eastern European Restaurant
# 4           Fast Food Restaurant
# 5           Fast Food Restaurant
# 6                      Drugstore
# 7            Empanada Restaurant
# 8                       Pharmacy
# 9                     Restaurant
# 10              Doner Restaurant
# 11                     Drugstore
# 12                     Drugstore
# 13           Sporting Goods Shop
# 14       Comfort Food Restaurant
# 15                Breakfast Spot
# 16                    Donut Shop
# 17              Doner Restaurant
# 18            Dim Sum Restaurant
# 19              Doner Restaurant
# 20                  Concert Hall
# 22   Eastern European Restaurant
# 23                    Sports Bar
# 24                   Salad Place
# 25                    Baby Store
# 26            Dim Sum Restaurant
# 27              Doner Restaurant
# 28            Chinese Restaurant
# 29     Middle Eastern Restaurant
# 30              Asian Restaurant
# 31                          Café
# ..                           ...
# 68                    Donut Shop
# 69                   Flea Market
# 70                Discount Store
# 71                     Drugstore
# 72            Dim Sum Restaurant
# 73                 Metro Station
# 74                  Burger Joint
# 75                    Restaurant
# 76                Sandwich Place
# 77                    Donut Shop
# 78                    Donut Shop
# 79              Asian Restaurant
# 80                 Poutine Place
# 81             Fish & Chips Shop
# 82                      Pharmacy
# 84                 Grocery Store
# 86                  Liquor Store
# 87                  Airport Gate
# 88                          Café
# 89                    Comic Shop
# 90                  Burger Joint
# 92                Breakfast Spot
# 93                  Dessert Shop
# 94                    Donut Shop
# 96                       Butcher
# 97                         Hotel
# 99                   Men's Store
# 100             Recording Studio
# 101                 Dessert Shop
# 102                       Bakery
#
# [90 rows x 12 columns]

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                  Borough  Cluster Labels 1st Most Common Venue  \
# 0             North York             3.0                  Park
# 21                  York             3.0                  Park
# 35             East York             3.0                  Park
# 64         York, Toronto             3.0                  Park
# 66            North York             3.0                  Park
# 83       Central Toronto             3.0                  Park
# 85  Scarborough, Toronto             3.0                  Park
# 91      Downtown Toronto             3.0                  Park
# 98             Etobicoke             3.0                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0      Food & Drink Shop      Department Store  Ethiopian Restaurant
# 21         Women's Store                Market            Donut Shop
# 35     Convenience Store           Coffee Shop    Dim Sum Restaurant
# 64     Convenience Store           Event Space  Ethiopian Restaurant
# 66                  Bank     Convenience Store  Ethiopian Restaurant
# 83            Playground          Tennis Court            Restaurant
# 85            Playground      Doner Restaurant      Department Store
# 91                 Trail            Playground          Dessert Shop
# 98                 River         Deli / Bodega   Empanada Restaurant
#
#    5th Most Common Venue        6th Most Common Venue  \
# 0    Empanada Restaurant            Electronics Store
# 21    Dim Sum Restaurant                        Diner
# 35                 Diner               Discount Store
# 64   Empanada Restaurant            Electronics Store
# 66   Empanada Restaurant            Electronics Store
# 83   Dumpling Restaurant                    Drugstore
# 85          Dessert Shop           Dim Sum Restaurant
# 91    Dim Sum Restaurant                        Diner
# 98     Electronics Store  Eastern European Restaurant
#
#           7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0   Eastern European Restaurant   Dumpling Restaurant             Drugstore
# 21               Discount Store               Dog Run      Doner Restaurant
# 35                      Dog Run      Doner Restaurant            Donut Shop
# 64  Eastern European Restaurant   Dumpling Restaurant      Department Store
# 66  Eastern European Restaurant   Dumpling Restaurant          Dessert Shop
# 83  Eastern European Restaurant            Donut Shop      Doner Restaurant
# 85                        Diner        Discount Store               Dog Run
# 91               Discount Store               Dog Run      Doner Restaurant
# 98          Dumpling Restaurant             Drugstore            Donut Shop
#
#    10th Most Common Venue
# 0              Donut Shop
# 21    Dumpling Restaurant
# 35              Drugstore
# 64              Drugstore
# 66              Drugstore
# 83           Dance Studio
# 85             Donut Shop
# 91             Donut Shop
# 98       Doner Restaurant

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                  Borough  Cluster Labels 1st Most Common Venue  \
# 51  Scarborough, Toronto             4.0   American Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 51                 Motel      Department Store    Dim Sum Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 51                 Diner        Discount Store               Dog Run
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 51      Doner Restaurant            Donut Shop            Yoga Studio
